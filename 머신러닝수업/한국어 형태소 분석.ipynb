# %% [markdown]
# ### 한국어 형태소 분석기
# - Hannanum
# - Kkma
# - Komoran
# - Mecab
# - Okt(어간추출가능)
# - Khaii

# %% [markdown]
# ### Okt 형태소 분석기 사용

# %%
from konlpy.tag import Okt
okt = Okt() # 형태소, 명사만, 어절, 품사태깅
#okt = Okt(stem=True) 어간추출사용시

# %%
data = '나 오늘 집에 진짜 앉아서 가고싶다.'

# %%
# 형태소 단위로 분석
okt.morphs(data)
# Out:
# ['나', '오늘', '집', '에', '진짜', '앉아서', '가고싶다', '.']

# %%
# 명사추출
okt.nouns(data)
# Out:
# ['나', '오늘', '집', '진짜']

# %%
# 어절 추출
okt.phrases(data)
# Out:
# ['나 오늘', '나 오늘 집', '진짜', '오늘']

# %%
# 품사 태깅
okt.pos(data)
# Out:
# [('나', 'Noun'),
#  ('오늘', 'Noun'),
#  ('집', 'Noun'),
#  ('에', 'Josa'),
#  ('진짜', 'Noun'),
#  ('앉아서', 'Verb'),
#  ('가고싶다', 'Verb'),
#  ('.', 'Punctuation')]

# %% [markdown]
# ### 단어빈도 계산

# %%
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ratings.txt', delimiter='\t')
df
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3        9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ;;      0
# 199996   3302770                                              쓰.레.기      0
# 199997   5458175                  완전 사이코영화. 마지막은 더욱더 이 영화의질을 떨어트린다.      0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [200000 rows x 3 columns]

# %%
x = df['document'][:3000]

# %%
n = [] #x값을 리스트에 담기
for i in x:
    n.append(i) 
print(n)
# Out:
# ['어릴때보고 지금다시봐도 재밌어요ㅋㅋ', '디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산업이 부러웠는데. 사실 우리나라에서도 그 어려운시절에 끝까지 열정을 지킨 노라노 같은 전통이있어 저와 같은 사람들이 꿈을 꾸고 이뤄나갈 수 있다는 것에 감사합니다.', '폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.', '와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런게 진짜 영화지', '안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.', '사랑을 해본사람이라면 처음부터 끝까지 웃을수 있는영화', '완전 감동입니다 다시봐도 감동', '개들의 전쟁2 나오나요? 나오면 1빠로 보고 싶음', '굿', '바보가 아니라 병 쉰 인듯', '내 나이와 같은 영화를 지금 본 나는 감동적이다..하지만 훗날 다시보면대사하나하나 그 감정을완벽하게 이해할것만 같다...', '재밌다', '고질라니무 귀엽다능ㅋㅋ', '영화의 오페라화라고 해야할 작품. 극단적 평갈림은 어쩔 수 없는 듯.', '3도 반전 좋았제 ^^', '평점 왜 낮아? 긴장감 스릴감 진짜 최고인데 진짜 전장에서 느끼는 공포를 생생하게 전해준다.', '네고시에이터랑 소재만 같을 뿐.. 아무런 관련없음..', '단연 최고', '가면 갈수록 더욱 빠져드네요 밀회 화이팅!!', '어?생각없이 봤는데 상당한 수작.일본영화 10년내 최고로 마음에 들었다.강렬한 임팩트가 일품.', '오랜만에 본 제대로 된 범죄스릴러~', "그런 때가 있었다. ('사랑해'도 아니고) 그저 좋아한다는 한 마디 말을 꺼내기도 벅차서 밤 잠 설치던 때. 커징텅의 교복에 남은 션자이의 볼펜 자국 역시 미처 다 전하지 못한 마음의 형태인 거다.", '마지막씬을 잊을수가 없다', '강압적용서,세뇌적용서에 대한 비판', '중세시대명작. 굿 평점이왜이래', '7시간짜리 영상이 존재한다면, 죽기전에 꼭 한번 보고싶다. 아름답고 슬픈 OST, 제니퍼코넬리의 눈부신 아역시절, 로버트드니로의 마지막 웃는 장면까지 정말 가슴속에 영원히 기억될 최고의 명작이다.', '사람이 어떻게 저런짓을 할 수가 있는지ㅡㅡ 보는 내가 다 화나더라', '인간의 잠재된 악마성은 여러 시간과 공간 속에서 존속해왔다. 이 다큐는 그것을 엉뚱하면서도 광적으로 재현하였다.', '최고다. 삼일동안 쉬는틈틈이 잠도 줄여가면서 봤다..여운이 남는다.', '실화여서 더욱 충격, 다시는 어디에서도 일어나서는 안될 경각심을 일깨워주는 영화', '존 그라샴 작품이라면 한번쯤은 볼가치가 있지', '농아인문화에 대한 알아야 합니다.', '이거어렸을때되게재밌게봄ㅋㅋ이정재 이범수ㅋㅋㅋㅋ연기쩜', '친구의 우정이 매우 감동적이었다', '굿굿굿 또해라또해라 제발 ㅠㅠ', '아 재미있다. 이 말이 너무 어울린다.', '제이크 질렌할..넌 대체 못하는 연기가 뭐냐.', '보는내내 입가에 미소가 샤방샤방했던 영화.', '원표가 왜 조연이양... 젤 많이 나오는구만...ㅋㅋ 재미있음...', '마치 바다속 , 아쿠아리움속으로 들어간듯한 느낌의 영화 어린자녀들에게 강추!!', '정의를 세우는 콜트, 콜텍 노동자들 이야기', '이 영화보면 브라질 가고싶은 마음이 사라질것이다.', '난 남자지만 영화내내 마음이 울렸다 그리고 내가 좋아하는 두 여배우 !!', '도법 멤버들 모두 기대됨', '정말 재미있게 본 영화였다 액션 최고', '내가 남자라그런가 이거 겁나 긴장감있고 흥미진진하던데..ㄷㄷ 나만그런가워낙에 격투씬을 좋아해서.ㅋㅋㅋ 그냥 아무생각없이 집에서 스마트티비로 봐서 재밌었나봄 이거 뭔영화인지도 모르고 암살에 나온 이정재 있길래 걍봄 ㅋㅋ 하여튼 너무 재밌게 봤음', '인정할건 인정하자 ㅆ파르 년들아 북한이 살만하고 좋으면 왜목숨걸고 대한민국 오는건데 어? 그거부터 납득시키고 나불거려라 종북 박평식같은 좋가튼년들아', '잊을 수 없는 그대여, 6월이 되고 비가 내려야 그대가 보이기 시작합니다.', '반가운 얼굴들~ㅋㅋㅋ 여주인공 넘 매력적이구~ 유쾌한영화였어요~~', '내용이너무좋아요.ㅎ', '정말 요즘 아이돌들이 다 배우 해먹네 할정도로 연기를 잘한다', '정말재밋게 봣는대요 어디서 받을수잇조?', '탱고 음악의 감동이 밀려온다.', '평생 못봤으면 후회할뻔한 따뜻한 명작', '이런 드라마가 많이 나왔으면 좋겠어요. 생각할 것도 많고 영상미도 아름답고 캐릭터도 다 매력 있었어요. 여러가지로 다 매력 있었던 드라마였어요.', '정말 최고였는데.. 마지막이.. 이련결말. 싫다..ㅠ', '너무 슬프네요. 왜 이제 알게된 영화였는지.', '잔잔하고 재미도 있어서 좋았다', '내가 본 영화 중 영순위♥', '재밌습니다.재밌습니다.', '상당히 훌륭한 영화...', '역시신동엽ㅋ순간 캐치 탁!얄밉게 웃긴 미워할수없고감탄!이영자랑 함 대박일텐데 왠이동욱?', '내 인생의 영화', '전작에 비해 떨어지는건 사실이지만 쓰레기 한국영화도 4점대 별로없는데 헐...니들 너무하다?', '지금은 다소 진부할수있어도 그당시엔 눈물 한사발 흘리게해준 영화.', '신부로서의 사명감을 처절히 실천하는 제리, 자신마저 부정하는 로키의 우정', '3.14 원주율메이커', '추석때 특선영화 해주는거 봤는데 진짜 가족들끼리 보기 좋은 영화였음!', '우리애기첫영화 너무너무 잘선택한거같아요""ㅎ굳', '재미있어요', '생각보다괜찬은조합인거같다', '저게바로 이시대의 어머니.', '나만 재밌으면 되지 뭐나도 원작 본 사람이지만 드래곤볼 에볼루션보다는 잘 만듬 ㅇㅇ', '우리나라 예능 중 최고!!', '방학때 아침에 졸린눈 비비면서 우연히 티비채널 돌리다 이 영화를 보게된건 정말..', '마음이 너무 아프다. 이 영화는 다시 볼 수 없을 것 같다.', '엔트랩먼트', '정말 재미있게 보았음. 권력에는 친구도 의리도 없다는 역사적 사실을 훌륭하게 깨우쳐줌.', '처음에는 초롱 팬심으로 봤는데 갈수록 내용과 어울리는 배경음악들이 너무 달달하고 보고 있으면 행복해지네요. 완전 재밌습니다.', '너무너무재밌게보고있어요! 중간부터 본방사수했지만 스토리가 탄탄하고 흥미진진해서 1화부터 다찾아서 봤네요 배우들 연기도 어디하나빠지는데가없네요 요새는 수백향만챙겨봐요', '내가 없어질 내인생. 제목을 참 잘 지었다.', '음 화질은좋은데재미가없네', '가을로 는 가을에 감동이네요', 'ost 때문에 봤는데 이건뭐 와~~라는 말밖에 안나오네 벌써 16년전인데 이런퀄리티가 나오다니 대단하다', '중3인데 일단 2까지봣다. 뭐 말할것도없다장국영 자살이 안타깝다', '사실적이어서 더 극적인.', '뀰잼이다뀰잼이라구여', '짱 재미있어요오> ㅇ <', '첫느낌은예전에양심냉장고와 비슷한거같더라고요 보면서 감정이움찔 해져요 그런대 한가지부탁 드리고싶은게연기자좀보호해주세요 욕이나폭력은 걱정되요 저어릴적에성추행을상가에서모든사람이목격했는데저만증언했었거든요덕분에청소년인저는계속경찰서를왔다갔다해야했죠', '남자주인공 넘 섹시하고 멋있쪙ㅋㅋㅋㅋ', '어설픈건 사실이었다 하지 재밋었다 ㅎ', 'SF영화 중 21세기 최고라고 할 수 있다..이걸 평점 낮게주는 사람은 정말 볼줄을 모르는것', '95년에 비디오방에서 친구랑 봤는데 정말 좋았다는 느낌이 지금까지...또 보고싶네요', '빨리 보고싶다!!!헌데 오래 기다려야 될거가틈...', '남기남 감독 그 이름 하나 만으로도 10점', '진짜 최고다 최고 성룡형님 마이 우상', 'amy6250 당신이 좋아하는 장르는 뭐요? 이영화에도 저영화에도 이런장르는 싫다니원', '지금까지 본영화중에 최고다', '매회리타가자꾸거슬려서죽었으면좋겠다고생각했는데ㅠㅠ죄책감에나도잠못이룬다.', '어릴 때보고 커서 다시 봤는데. 진짜 잘 만든 영화였네. 웃음과 감동을 잘 이어 붙였고 정치에 대한 비판이랑 묘사도 굉장히 잘 표현했다. 흥행했었는지 기억은 안나지만 절대 낮은 평점의 영화가 아니라고 생각한다. 연기자들 연기하는 디테일만 봐도 따봉임', '대박이였지 이건 한마디로..', '사랑은 달기만한게 아니라는거.', '마음을 파고든다.... 볼 수록 빠져드는 영화..', '13살이엇냐?...', '남자 얼굴 성격 10점만점에 10000점', '잼있어요! 다음에 ㄸㅗ보고싶어 ...

# %%
okt = Okt()
noun = okt.nouns(str(n))

# %%
count = Counter(noun)
count
# Out:
# Counter({'때': 106,
#          '보고': 119,
#          '지금': 66,
#          '다시': 94,
#          '디자인': 1,
#          '학생': 5,
#          '외국': 1,
#          '디자이너': 1,
#          '그': 94,
#          '일군': 1,
#          '전통': 5,
#          '통해': 9,
#          '발전': 6,
#          '문화': 4,
#          '산업': 2,
#          '사실': 20,
#          '우리나라': 9,
#          '시절': 10,
#          '끝': 23,
#          '열정': 7,
#          '노라노': 1,
#          '저': 33,
#          '사람': 110,
#          '꿈': 17,
#          '수': 88,
#          '것': 121,
#          '폴리스스토리': 1,
#          '시리즈': 24,
#          '부터': 5,
#          '뉴': 1,
#          '하나': 54,
#          '최고': 230,
#          '연기': 142,
#          '진짜': 184,
#          '개': 24,
#          '생각': 140,
#          '몰입': 20,
#          '영화': 985,
#          '안개': 2,
#          '밤하늘': 1,
#          '초승달': 1,
#          '사랑': 78,
#          '라면': 16,
#          '처음': 36,
#          '완전': 53,
#          '감동': 155,
#          '전쟁': 20,
#          '빠': 4,
#          '굿': 37,
#          '바보': 4,
#          '병': 4,
#          '쉰': 1,
#          '내': 90,
#          '나이': 15,
#          '나': 65,
#          '훗날': 1,
#          '사하나': 2,
#          '감정': 18,
#          '이해': 40,
#          '고질': 1,
#          '무': 5,
#          '능': 2,
#          '오페라': 7,
#          '작품': 67,
#          '극단': 1,
#          '평': 6,
#          '갈림': 1,
#          '듯': 51,
#          '도': 19,
#          '반전': 23,
#          '제': 22,
#          '평점': 103,
#          '왜': 70,
#          '긴장감': 21,
#          '스릴': 13,
#          '감': 19,
#          '전장': 2,
#          '공포': 12,
#          '전': 22,
#          '고시': 1,
#          '터': 5,
#          '소재': 25,
#          '뿐': 16,
#          '관련': 2,
#          '단연': 3,
#          '가면': 4,
#          '갈수록': 12,
#          '더욱': 11,
#          '드': 8,
#          '밀회': 1,
#          '화이팅': 9,
#          '수작': 18,
#          '일본': 7,
#          '마음': 56,
#          '임팩트': 2,
#          '일품': 5,
#          '만': 26,
#          '제대로': 16,
#          '범죄': 4,
#          '스릴러': 16,
#          '마디': 3,
#          '말': 73,
#          '밤': 9,
#          '잠': 2,
#          '징텅': 1,
#          '교복': 1,
#          '션': 2,
#          '이의': 1,
#          '볼펜': 1,
#          '자국': 1,
#          '역시': 37,
#          '미처': 2,
#          '전하': 2,
#          '못': 18,
#          '형태': 2,
#          '거': 75,
#          '마지막': 80,
#          '씬': 15,
#          '강압': 1,
#          '용서': 2,
#          '세뇌': 1,
#          '대한': 26,
#          '비판': 7,
#          '중세시대': 1,
#          '명작': 61,
#          '영상': 26,
#          '존재': 10,
#          '꼭': 46,
#          '한번': 40,
#          '제니퍼': 3,
#          '코넬': 1,
#          '리': 3,
#          '아역시절': 1,
#          '로버트': 6,
#          '드니': 5,
#          '의': 20,
#          '장면': 49,
#          '정말': 265,
#          '가슴속': 1,
#          '기억': 35,
#          '짓': 5,
#          '수가': 6,
#          '인간': 33,
#          '잠재': 1,
#          '악마': 1,
#          '성은': 1,
#          '여러': 4,
#          '시간': 33,
#          '공간': 4,
#          '속': 24,
#          '존속': 1,
#          '이': 155,
#          '다큐': 11,
#          '그것': 7,
#          '광': 1,
#          '재현': 1,
#          '최고다': 27,
#          '삼일': 1,
#          '동안': 4,
#          '틈틈이': 1,
#          '잠도': 2,
#          '여운': 35,
#          '실화': 17,
#          '충격': 9,
#          '어디': 9,
#          '일어나서': 2,
#          '각심': 1,
#          '일': 15,
#          '존': 3,
#          '그라샴': 1,
#          '농아인': 1,
#          '봄': 15,
#          '이정재': 2,
#          '이범수': 1,
#          '쩜': 1,
#          '친구': 16,
#          '우정': 6,
#          '매우': 13,
#          '굿굿굿': 1,
#          '또': 45,
#          '또해': 1,
#          '제발': 3,
#          '제이크': 1,
#          '질렌할': 2,
#          '넌': 4,
#          '대체': 4,
#          '뭐': 35,
#          '입가': 2,
#          '미소': 7,
#          '샤방샤방했던': 1,
#          '원표': 1,
#          '조연': 3,
#          '이양': 1,
#          '젤': 4,
#          '마치': 5,
#          '바다': 4,
#          '아쿠아리움': 1,
#          '느낌': 47,
#          '자녀': 1,
#          '강추': 19,
#          '정의': 4,
#          '콜트': 2,
#          '콜텍': 1,
#          '노동자': 3,
#          '이야기': 43,
#          '화보': 4,
#          '브라질': 2,
#          '난': 39,
#          '남자': 34,
#          '내내': 16,
#          '두': 8,
#          '여배우': 9,
#          '도법': 1,
#          '멤버': 1,
#          '모두': 24,
#          '기대': 20,
#          '액션': 45,
#          '런가': 5,
#          '흥미진진': 9,
#          '워낙': 1,
#          '격투씬': 1,
#          '그냥': 43,
#          '집': 8,
#          '스마트': 1,
#          '티비': 14,
#          '인지도': 1,
#          '암살': 1,
#          '하여튼': 1,
#          '인정': 7,
#          '파르': 1,
#          '년': 12,
#          '북한': 3,
#          '살': 18,
#          '목숨': 5,
#          '대한민국': 8,
#          '그거': 2,
#          '납득': 1,
#          '나불': 1,
#          '거려': 1,
#          '종북': 2,
#          '박평': 1,
#          '그대': 4,
#          '비': 8,
#          '시작': 9,
#          '얼굴': 10,
#          '주인공': 42,
#          '매력': 49,
#          '이구': 1,
#          '용이': 5,
#          '요즘': 17,
#          '아이돌': 4,
#          '배우': 65,
#          '해먹': 1,
#          '정도': 42,
#          '정말재밋': 1,
#          '봣는대': 1,
#          '조': 2,
#          '탱고': 1,
#          '음악': 37,
#          '평생': 7,
#          '후회': 17,
#          '드라마': 121,
#          '미도': 2,
#          '캐릭터': 19,
#          '여러가지': 3,
#          '결말': 30,
#          '이제': 10,
#          '알': 34,
#          '재미': 59,
#          '중': 43,
#          '순위': 2,
#          '신동엽': 1,
#          '순간': 8,
#          '캐치': 1,
#          '탁': 1,
#          '감탄': 5,
#          '이영자': 1,
#          '함': 23,
#          '대박': 32,
#          '이동욱': 1,
#          '인생': 38,
#          '전작': 2,
#          '쓰레기': 7,
#          '한국영': 18,
#          '점': 107,
#          '별로': 16,
#          '니': 11,
#          '다소': 4,
#          '당시': 22,
#          '눈물': 34,
#          '사발': 1,
#          '신부': 1,
#          '로서': 5,
#          '명감': 2,
#          '실천': 1,
#          '제리': 2,
#          '자신': 21,
#          '부정': 1,
#          '로키': 1,
#          '원주율': 1,
#          '메이커': 2,
#          '추석': 1,
#          '특선영화': 1,
#          '가족': 30,
#          '끼리': 4,
#          '보기': 26,
#          '우리': 34,
#          '애기': 4,
#          '선택': 9,
#          '괜찬': 1,
#          '조합': 5,
#          '게': 14,
#          '바로': 8,
#          '대의': 2,
#          '어머니': 6,
#          '원작': 13,
#          '드래곤볼': 1,
#          '에볼루션': 1,
#          '만듬': 1,
#          '예능': 2,
#          '방학': 2,
#          '아침': 1,
#          '눈': 25,
#          '채널': 3,
#          '볼': 66,
#          '엔트랩먼트': 1,
#          '권력': 6,
#          '의리': 8,
#          '역사': 8,
#          '줌': 6,
#          '초롱': 1,
#          '팬심': 1,
#          '내용': 46,
#          '배경음악': 3,
#          '달달': 4,
#          '중간': 18,
#          '본방': 7,
#          '사수': 6,
#          '스토리': 69,
#          '화': 3,
#          '요새': 2,
#          '수백향': 2,
#          '제목': 18,
#          '음': 11,
#          '화질': 1,
#          '가을로': 1,
#          '가을': 2,
#          '요': 24,
#          '때문': 23,
#          '이건': 21,
#          '벌써': 7,
#          '퀄리티': 7,
#          '일단': 4,
#          '까지봣다': 1,
#          '장국영': 2,
#          '자살': 2,
#          '더': 91,
#          '극적': 1,
#          '뀰잼': 2,
#          '구': 11,
#          '짱': 26,
#          '오': 10,
#          '예전': 7,
#          '양심': 4,
#          '냉장고': 1,
#          '움찔': 1,
#          '한가지': 1,
#          '부탁': 1,
#          '연기자': 5,
#          '좀': 40,
#          '보호': 2,
#          '욕': 4,
#          '폭력': 4,
#          '걱정': 2,
#          '적': 18,
#          '성추행': 1,
#          '상가': 1,
#          '모든': 25,
#          '목격': 1,
#          '증언': 1,
#          '덕분': 6,
#          '청소년': 2,
#          '는': 1,
#          '계속': 23,
#          '경찰서': 1,
#          '멋있쪙': 1,
#          '재밋었다': 1,
#          '세기': 6,
#          '걸': 30,
#          '비디오': 8,
#          '방': 6,
#          '틈': 4,
#          '남기남': 1,
#          '감독': 47,
#          '이름': 10,
#          '성룡': 14,
#          '형님': 6,
#          '마이': 5,
#          '우상': 2,
#          '당신': 11,
#          '장르': 7,
#          '이영화': 52,
#          '원': 2,
#          '리타': 1,
#          '자꾸': 9,
#          '죄책감': 2,
#          '도잠': 1,
#          '커서': 3,
#          '웃음': 16,
#          '정치': 5,
#          '묘사': 5,
#          '표현': 18,
#          '흥행': 5,
#          '안나': 3,
#          '절대': 13,
#          '디테': 2,
#          '일만': 1,
#          '봉임': 1,
#          '한마디': 10,
#          '달기': 1,
#          '수록': 2,
#          '살이': 1,
#          '엇냐': 1,
#          '성격': 4,
#          '만점': 14,
#          '다음': 8,
#          '핡': 2,
#          '초반': 8,
#          '설정': 3,
#          '점차': 1,
#          '판타지': 4,
#          '미래': 6,
#          '현실': 46,
#          '언론': 1,
#          '탄압': 1,
#          '은유': 1,
#          '오카다': 1,
#          '예상': 4,
#          '별': 8,
#          '의외': 3,
#          '인도영화': 1,
#          '무엇': 23,
#          '다그': 2,
#          '웃': 4,
#          '허정무': 1,
#          '대신': 1,
#          '장외룡': 1,
#          '한국': 32,
#          '국': 2,
#          '고고싱': 1,
#          '어찌': 6,
#          '보조개': 1,
#          '메이': 2,
#          '최고봉': 5,
#          '초딩': 11,
#          '봣음': 2,
#          '비포미드나잇': 1,
#          '심정': 4,
#          '또한': 7,
#          '한편': 5,
#          '모습': 29,
#          '절로': 5,
#          '뭔가': 19,
#          '코': 8,
#          '스케': 1,
#          '라디오': 1,
#          '임진강': 1,
#          '한석규': 4,
#          '쵝오': 7,
#          '허니': 3,
#          '잼': 14,
#          '꿀잼': 10,
#          '개꿀잼': 1,
#          '한예슬': 1,
#          '원래': 4,
#          '옷': 1,
#          '헤어': 1,
#          '메이크업': 1,
#          '반': 2,
#          '네': 3,
#          '훈남': 2,
#          '쉐프': 1,
#          '보구': 4,
#          '요리': 4,
#          '시나리오': 7,
#          '비고': 1,
#          '슨': 2,
#          '잼잼꿀잼': 1,
#          '잼핵잼잼잼': 1,
#          '개인': 24,
#          '언제': 12,
#          '팬텀': 3,
#          '크리스틴': 2,
#          '일이': 4,
#          '전혀': 13,
#          '처럼': 3,
#          '남편': 3,
#          '곁': 1,
#          '아쉬움': 4,
#          '알파': 2,
#          '치노': 2,
#          '명화': 6,
#          '뮤지컬': 8,
#          '역대': 6,
#          '위': 16,
#          '대부': 1,
#          '바람': 5,
#          '레벨': 1,
#          '명의': 2,
#          '마잭': 1,
#          '마돈나': 1,
#          '엘비스급': 1,
#          '춤': 4,
#          '노래실력': 1,
#          '바비': 3,
#          '바스코': 3,
#          '이번': 7,
#          '결과': 3,
#          '대해': 20,
#          '불만': 1,
#          '어쩌면': 4,
#          '거지': 7,
#          '어쩌': 1,
#          '자격': 1,
#          '코미디': 18,
#          '사극': 3,
#          '장혁': 1,
#          '명품': 5,
#          '땐': 5,
#          '온': 3,
#          '이서': 2,
#          '마련': 1,
#          '사마': 1,
#          '그날': 3,
#          '저녁': 1,
#          '기분': 17,
#          '탓': 2,
#          '진': 11,
#          '옛날': 8,
#          '워낭소리': 1,
#          '더빙': 7,
#          '자막': 6,
#          '데': 17,
#          '뒤': 8,
#          '포': 2,
#          '씨': 4,
#          '연말': 2,
#          '추천': 50,
#          '사회': 14,
#          '치부': 1,
#          '예언': 1,
#          '엣날': 1,
#          '제일': 17,
#          '슈퍼': 3,
#          '울트라': 1,
#          '초': 4,
#          '노막': 1,
#          '입': 3,
#          '중동': 1,
#          '명': 9,
#          '참여': 1,
#          '길': 7,
#          '얼마나': 9,
#          '아버지': 10,
#          '이자': 7,
#          '무사': 2,
#          '일생': 1,
#          '의미': 10,
#          '죽음': 5,
#          '일지': 5,
#          '신념': 4,
#          '멋': 2,
#          '진일': 1,
#          '물결': 2,
#          '안': 26,
#          '쵝오임': 1,
#          '다만': 8,
#          '엔딩': 18,
#          '배심원': 2,
#          '상대로': 1,
#          '일장': 1,
#          '연설': 2,
#          '작위': 1,
#          '신파': 1,
#          '무죄': 1,
#          '애정': 2,
#          '둘': 6,
#          '멜로': 5,
#          '최영장군': 1,
#          '이민호': 2,
#          '안치환': 1,
#          '방향': 1,
#          '노래': 19,
#          '걸작': 14,
#          '안보': 8,
#          '고도': 2,
#          '오스트레일리아': 1,
#          '조금': 15,
#          '프랑스': 5,
#          '식': 4,
#          '신': 5,
#          '심장': 4,
#          '쫄깃하': 1,
#          '준': 8,
#          '웰': 3,
#          '메이드': 3,
#          '범죄물': 1,
#          '류승범': 2,
#          '황정민': 2,
#          '기쁨': 3,
#          '배': 7,
#          '등장인물': 1,
#          '절제': 2,
#          '소설가': 1,
#          '답': 3,
#          '무척': 7,
#          '엄마': 17,
#          '운전': 1,
#          '맥거핀': 1,
#          '아이맥스': 1,
#          '로': 13,
#          '개봉': 15,
#          '거임': 2,
#          '완죤': 1,
#          '스타': 6,
#          '정부': 2,
#          '국민': 7,
#          '의지': 3,
#          '퀘벡': 1,
#          '호킹': 1,
#          '능욕': 1,
#          '누': 1,
#          '보통': 1,
#          '전쟁영화': 4,
#          '특유': 5,
#          '연출': 25,
#          '이정현': 2,
#          '전형': 3,
#          '사이코': 1,
#          '갠': 1,
#          '우릴': 1,
#          '손': 8,
#          '욕망': 3,
#          '명대사': 3,
#          '편': 32,
#          '똥칠': 1,
#          '된거': 2,
#          '점도': 2,
#          '블레이드러너': 1,
#          '버금': 2,
#          '임': 24,
#          '결코': 2,
#          '정일우': 2,
#          '상투': 1,
#          '존경': 4,
#          '반지': 2,
#          '제왕': 3,
#          '피터': 1,
#          '잭슨': 1,
#          '영': 5,
#          '감독판': 1,
#          '쩌': 2,
#          '캬': 3,
#          '추억': 17,
#          '녹화': 2,
#          '번': 27,
#          '리메이크': 4,
#          '무협': 2,
#          '보너스': 1,
#          '시내': 1,
#          '보신': 3,
#          '강': 8,
#          '추강': 2,
#          '추': 3,
#          '아이': 26,
#          '만화영화': 3,
#          '액션영화': 7,
#          '서도': 1,
#          '귀수': 1,
#          '아군': 1,
#          '첫사랑': 6,
#          '설레임': 1,
#          '그대로': 9,
#          '관람': 9,
#          '향수': 2,
#          '김민선': 1,
#          '김규리': 1,
#          '여신': 4,
#          '미모': 2,
#          '움': 15,
#          '힐링': 6,
#          '무비': 8,
#          '자리': 4,
#          '연속': 2,
#          '질리': 8,
#          '외계인': 1,
#          '역': 4,
#          '신분': 3,
#          '맥': 3,
#          '라이언': 3,
#          '애니': 17,
#          '판': 7,
#          '코드': 4,
#          '반영': 4,
#          '짜임새': 6,
#          '러브': 2,
#          '모드': 1,
#          '여주': 4,
#          '어요': 1,
#          '하나요': 1,
#          '시간여행': 1,
#          '류': 5,
#          '트릴': 1,
#          '방송': 6,
#          '털털': 1,
#          '실제': 12,
#          '분': 20,
#          '시기': 4,
#          '나중': 5,
#          '입문': 1,
#          '가연': 1,
#          '세': 6,
#          '물감': 1,
#          '시': 4,
#          '애가': 1,
#          '주제': 4,
#          '배급사': 1,
#          '싸이코패스': 1,
#          '안인숙': 1,
#          '이편': 1,
#          '조각': 1,
#          '재밋': 15,
#          '용도': 3,
#          '케미': 4,
#          '이예': 1,
#          '여유': 3,
#          '일요일': 1,
#          '오후': 1,
#          '동화': 4,
#          '세계': 9,
#          '스타워즈': 2,
#          '쌍탑': 1,
#          '날': 12,
#          '문': 1,
#          '불': 2,
#          '일견': 1,
#          '남': 15,
#          '녀': 5,
#          '알콜중독': 1,
#          '의문': 3,
#          '겉보기': 1,
#          '안정': 1,
#          '그녀': 20,
#          '외로움': 2,
#          '아픔': 10,
#          '술': 2,
#          '로써': 2,
#          '이유': 11,
#          '삶': 28,
#          '내생': 2,
#          '가장': 26,
#          '여명': 2,
#          '눈동자': 1,
#          '허준': 1,
#          '모래시계': 1,
#          '황금의제국': 1,
#          '규모': 1,
#          '사업가': 1,
#          '집안': 1,
#          '갈등': 3,
#          '서로': 3,
#          '원수': 1,
#          '필름': 1,
#          '무당': 1,
#          '인': 3,
#          '방이': 1,
#          '맘': 16,
#          '듬': 4,
#          '들개': 1,
#          '해외': 1,
#          '수니': 1,
#          '웁니': 1,
#          '가원': 1,
#          '웃기': 14,
#          '해지': 2,
#          '소녀시대': 3,
#          '앞': 14,
#          '윤아': 2,
#          '잘못': 3,
#          '박한별': 2,
#          '송지효': 3,
#          '조안': 1,
#          '싸이코': 3,
#          '역할': 6,
#          '나름': 13,
#          '몸매': 2,
#          '부분': 24,
#          '주연': 4,
#          '열': 1,
#          '쥐': 3,
#          '목소리': 9,
#          '간직': 2,
#          '사람과': 3,
#          '리가': 2,
#          '폭풍': 4,
#          '집중': 9,
#          '도리': 1,
#          '글쎄': 1,
#          '알라': 1,
#          '미움': 1,
#          '가르침': 1,
#          '모슬렘': 2,
#          '신고': 2,
#          '애국': 1,
#          '미국': 8,
#          '시민': 1,
#          '말로': 6,
#          '교회': 1,
#          '반성': 5,
#          '기독교인': 1,
#          '래야': 4,
#          '나마': 1,
#          '행운': 2,
#          '엔딩크레딧': 1,
#          '발견': 9,
#          '목록': 1,
#          '배경': 17,
#          '틀': 4,
#          '휴식': 2,
#          '난리': 2,
#          '람보': 1,
#          '터미네이터': 3,
#          '맥클레인': 1,
#          '얘기': 11,
#          '재밋다': 11,
#          '혼자': 11,
#          '올해': 3,
#          '짱짱': 11,
#          '몇': 7,
#          '눈빛': 6,
#          '생동감': 1,
#          '몸짓': 1,
#          '발짓': 1,
#          '거의': 8,
#          '강아지': 2,
#          '토토': 1,
#          '껄': 1,
#          '흐름': 2,
#          '희망': 10,
#          '슬픔': 5,
#          '비극': 6,
#          '동전': 2,
#          '양면': 2,
#          '어릴떄': 1,
#          '아빠': 6,
#          '매일': 2,
#          '넷': 1,
#          '지오': 2,
#          '자연': 9,
#          '압도': 8,
#          '힘': 11,
#          '댄스': 1,
#          '퀸': 2,
#          '롤라': 1,
#          '찬': 3,
#          '새해': 1,
#          '아따맘마': 1,
#          '리지': 1,
#          '널': 2,
#          '차태현': 3,
#          '패': 3,
#          '건': 14,
#          '박중훈': 4,
#          '아즈': 1,
#          '환상': 6,
#          '헤메': 1,
#          '막시무스': 2,
#          '빈민촌': 1,
#          '실상': 1,
#          '리얼': 6,
#          '영화로': 9,
#          '미화': 2,
#          '생명': 2,
#          '그름': 1,
#          '잣': 1,
#          '나라': 7,
#          '스스로': 3,
#          '정해': 2,
#          '그게': 6,
#          '앞뒤': 1,
#          '가까이': 2,
#          '뜻': 3,
#          '오만': 1,
#          '편견': 4,
#          '위트': 2,
#          '영화매니아': 1,
#          '지침': 1,
#          '다른': 12,
#          '미드': 3,
#          '재방송': 1,
#          '캐스팅': 3,
#          '한효주': 1,
#          '문채원': 3,
#          '회': 6,
#          '방금': 4,
#          '중학교': 2,
#          '담임': 1,
#          '선생님': 4,
#          '이후': 10,
#          '가끔': 8,
#          '백영규': 1,
#          '재난': 2,
#          '극치': 1,
#          '돋넼': 1,
#          '대부분': 3,
#          '완성': 12,
#          '코믹': 17,
#          '요소': 4,
#          '아치': 2,
#          '애환': 1,
#          '조음': 2,
#          '동물': 7,
#          '재밋는': 1,
#          '박유천': 2,
#          '한지민': 2,
#          '캐': 2,
#          '미가': 3,
#          '폭포': 1,
#          '탈출': 1,
#          '이전': 4,
#          '사상': 1,
#          '무렵': 1,
#          '델': 2,
#          '킴': 1,
#          '최진희': 2,
#          '로랑': 1,
#          '곡': 6,
#          '건가': 3,
#          '누가': 7,
#          '중국영화': 2,
#          '로맨스': 7,
#          '공존': 1,
#          '번은': 2,
#          '감히': 4,
#          '프레이져': 1,
#          '주걸륜': 1,
#          '머이쪙': 1,
#          '박력': 1,
#          '스턴': 1,
#          '트': 3,
#          '평작': 1,
#          '하정우': 2,
#          '개그': 7,
#          '단발': 1,
#          '의사': 2,
#          '샘': 3,
#          '적당': 1,
#          '넨': 1,
#          '재': 7,
#          '밋게봣': 1,
#          '봣던': 1,
#          '사관': 1,
#          '키스신': 3,
#          '예수님': 3,
#          '계기': 1,
#          '여': 8,
#          '모던': 2,
#          '시네마': 1,
#          '주의': 4,
#          '로맨틱': 4,
#          '조우': 1,
#          '키아로스타미': 1,
#          '이중': 1,
#          '운동': 1,
#          '믿음': 1,
#          '가슴': 43,
#          '정태우': 1,
#          '감사용': 2,
#          '패전': 3,
#          '처리': 3,
#          '투수': 2,
#          '전문': 3,
#          '패가': 1,
#          '이기': 3,
#          '무승부': 1,
#          '등판': 1,
#          '본인': 3,
#          '상대': 4,
#          '팀': 4,
#          '방어율': 1,
#          '전체': 6,
#          '옴니버스': 1,
#          '진행': 3,
#          '색감': 6,
#          '상상력': 5,
#          '킬림': 1,
#          '임용': 1,
#          '쿡': 3,
#          '낫다': 4,
#          '연애': 7,
#          ...})

# %%
# 명사 빈도 카운트
noun_list = count.most_common(100)

# %%
for i in noun_list:
    print(i)
# Out:
# ('영화', 985)
# ('정말', 265)
# ('최고', 230)
# ('진짜', 184)
# ('감동', 155)
# ('이', 155)
# ('연기', 142)
# ('생각', 140)
# ('것', 121)
# ('드라마', 121)
# ('보고', 119)
# ('사람', 110)
# ('점', 107)
# ('때', 106)
# ('평점', 103)
# ('다시', 94)
# ('그', 94)
# ('더', 91)
# ('내', 90)
# ('수', 88)
# ('마지막', 80)
# ('사랑', 78)
# ('거', 75)
# ('말', 73)
# ('왜', 70)
# ('스토리', 69)
# ('작품', 67)
# ('지금', 66)
# ('볼', 66)
# ('나', 65)
# ('배우', 65)
# ('명작', 61)
# ('재미', 59)
# ('마음', 56)
# ('하나', 54)
# ('완전', 53)
# ('이영화', 52)
# ('듯', 51)
# ('추천', 50)
# ('장면', 49)
# ('매력', 49)
# ('느낌', 47)
# ('감독', 47)
# ('꼭', 46)
# ('내용', 46)
# ('현실', 46)
# ('또', 45)
# ('액션', 45)
# ('이야기', 43)
# ('그냥', 43)
# ('중', 43)
# ('가슴', 43)
# ('주인공', 42)
# ('정도', 42)
# ('이해', 40)
# ('한번', 40)
# ('좀', 40)
# ('난', 39)
# ('인생', 38)
# ('굿', 37)
# ('역시', 37)
# ('음악', 37)
# ('처음', 36)
# ('기억', 35)
# ('여운', 35)
# ('뭐', 35)
# ('남자', 34)
# ('알', 34)
# ('눈물', 34)
# ('우리', 34)
# ('저', 33)
# ('인간', 33)
# ('시간', 33)
# ('대박', 32)
# ('한국', 32)
# ('편', 32)
# ('결말', 30)
# ('가족', 30)
# ('걸', 30)
# ('모습', 29)
# ('연기력', 29)
# ('삶', 28)
# ('최고다', 27)
# ('번', 27)
# ('만', 26)
# ('대한', 26)
# ('영상', 26)
# ('보기', 26)
# ('짱', 26)
# ('안', 26)
# ('아이', 26)
# ('가장', 26)
# ('소재', 25)
# ('눈', 25)
# ('모든', 25)
# ('연출', 25)
# ('여자', 25)
# ('시리즈', 24)
# ('개', 24)
# ('속', 24)

# %% [markdown]
# ### 단어 리스트 만들기

# %%
word_list = []
word_list = df['document'][:3000]

# %%
t = []
for i in word_list:
    morph = okt.pos(i)
    t.append(morph)

# %% [markdown]
# #### 명사추출

# %%
noun_list = []
for s in t:
    for word, tag in s:
        if tag in ['Noun']:
            noun_list.append(word)

# %% [markdown]
# #### 두글자 이상 단어만 추출

# %%
noun_list2 = [n for n in noun_list if len(n) > 1]

# %%
noun_list2
# Out:
# ['보고',
#  '지금',
#  '다시',
#  '디자인',
#  '학생',
#  '외국',
#  '디자이너',
#  '일군',
#  '전통',
#  '통해',
#  '발전',
#  '문화',
#  '산업',
#  '사실',
#  '우리나라',
#  '시절',
#  '열정',
#  '노라노',
#  '전통',
#  '사람',
#  '폴리스스토리',
#  '시리즈',
#  '부터',
#  '하나',
#  '최고',
#  '연기',
#  '진짜',
#  '생각',
#  '몰입',
#  '진짜',
#  '영화',
#  '안개',
#  '밤하늘',
#  '초승달',
#  '영화',
#  '사랑',
#  '사람',
#  '라면',
#  '처음',
#  '영화',
#  '완전',
#  '감동',
#  '다시',
#  '감동',
#  '전쟁',
#  '보고',
#  '바보',
#  '나이',
#  '영화',
#  '지금',
#  '감동',
#  '훗날',
#  '다시',
#  '사하나',
#  '감정',
#  '이해',
#  '고질',
#  '영화',
#  '오페라',
#  '작품',
#  '극단',
#  '갈림',
#  '반전',
#  '평점',
#  '긴장감',
#  '스릴',
#  '진짜',
#  '최고',
#  '진짜',
#  '전장',
#  '공포',
#  '고시',
#  '소재',
#  '관련',
#  '단연',
#  '최고',
#  '가면',
#  '갈수록',
#  '더욱',
#  '밀회',
#  '화이팅',
#  '생각',
#  '수작',
#  '일본',
#  '영화',
#  '최고',
#  '마음',
#  '임팩트',
#  '일품',
#  '제대로',
#  '범죄',
#  '스릴러',
#  '사랑',
#  '마디',
#  '징텅',
#  '교복',
#  '이의',
#  '볼펜',
#  '자국',
#  '역시',
#  '미처',
#  '전하',
#  '마음',
#  '형태',
#  '마지막',
#  '강압',
#  '용서',
#  '세뇌',
#  '용서',
#  '대한',
#  '비판',
#  '중세시대',
#  '명작',
#  '평점',
#  '영상',
#  '존재',
#  '한번',
#  '제니퍼',
#  '코넬',
#  '아역시절',
#  '로버트',
#  '드니',
#  '마지막',
#  '장면',
#  '정말',
#  '가슴속',
#  '기억',
#  '최고',
#  '명작',
#  '사람',
#  '수가',
#  '인간',
#  '잠재',
#  '악마',
#  '성은',
#  '여러',
#  '시간',
#  '공간',
#  '존속',
#  '다큐',
#  '그것',
#  '재현',
#  '최고다',
#  '삼일',
#  '동안',
#  '틈틈이',
#  '잠도',
#  '여운',
#  '실화',
#  '더욱',
#  '충격',
#  '어디',
#  '일어나서',
#  '각심',
#  '영화',
#  '그라샴',
#  '작품',
#  '라면',
#  '한번',
#  '농아인',
#  '문화',
#  '대한',
#  '이정재',
#  '이범수',
#  '연기',
#  '친구',
#  '우정',
#  '매우',
#  '감동',
#  '굿굿굿',
#  '또해',
#  '제발',
#  '제이크',
#  '질렌할',
#  '대체',
#  '연기',
#  '입가',
#  '미소',
#  '샤방샤방했던',
#  '영화',
#  '원표',
#  '조연',
#  '이양',
#  '마치',
#  '바다',
#  '아쿠아리움',
#  '느낌',
#  '영화',
#  '자녀',
#  '강추',
#  '정의',
#  '콜트',
#  '콜텍',
#  '노동자',
#  '이야기',
#  '화보',
#  '브라질',
#  '마음',
#  '남자',
#  '영화',
#  '내내',
#  '마음',
#  '여배우',
#  '도법',
#  '멤버',
#  '모두',
#  '기대',
#  '정말',
#  '영화',
#  '액션',
#  '최고',
#  '남자',
#  '런가',
#  '긴장감',
#  '흥미진진',
#  '런가',
#  '워낙',
#  '격투씬',
#  '그냥',
#  '생각',
#  '스마트',
#  '티비',
#  '영화',
#  '인지도',
#  '암살',
#  '이정재',
#  '하여튼',
#  '인정',
#  '인정',
#  '파르',
#  '북한',
#  '목숨',
#  '대한민국',
#  '그거',
#  '납득',
#  '나불',
#  '거려',
#  '종북',
#  '박평',
#  '그대',
#  '그대',
#  '시작',
#  '얼굴',
#  '주인공',
#  '매력',
#  '이구',
#  '영화',
#  '용이',
#  '정말',
#  '요즘',
#  '아이돌',
#  '배우',
#  '해먹',
#  '정도',
#  '연기',
#  '정말재밋',
#  '봣는대',
#  '탱고',
#  '음악',
#  '감동',
#  '평생',
#  '후회',
#  '명작',
#  '드라마',
#  '생각',
#  '영상',
#  '미도',
#  '캐릭터',
#  '매력',
#  '여러가지',
#  '매력',
#  '드라마',
#  '정말',
#  '최고',
#  '마지막',
#  '결말',
#  '이제',
#  '영화',
#  '재미',
#  '영화',
#  '순위',
#  '영화',
#  '역시',
#  '신동엽',
#  '순간',
#  '캐치',
#  '감탄',
#  '이영자',
#  '대박',
#  '이동욱',
#  '인생',
#  '영화',
#  '전작',
#  '사실',
#  '쓰레기',
#  '한국영',
#  '별로',
#  '지금',
#  '다소',
#  '당시',
#  '눈물',
#  '사발',
#  '영화',
#  '신부',
#  '로서',
#  '명감',
#  '실천',
#  '제리',
#  '자신',
#  '부정',
#  '로키',
#  '우정',
#  '원주율',
#  '메이커',
#  '추석',
#  '특선영화',
#  '진짜',
#  '가족',
#  '끼리',
#  '보기',
#  '영화',
#  '우리',
#  '애기',
#  '영화',
#  '선택',
#  '생각',
#  '괜찬',
#  '조합',
#  '바로',
#  '대의',
#  '어머니',
#  '원작',
#  '사람',
#  '드래곤볼',
#  '에볼루션',
#  '만듬',
#  '우리나라',
#  '예능',
#  '최고',
#  '방학',
#  '아침',
#  '티비',
#  '채널',
#  '영화',
#  '정말',
#  '마음',
#  '영화',
#  '다시',
#  '엔트랩먼트',
#  '정말',
#  '권력',
#  '친구',
#  '의리',
#  '역사',
#  '사실',
#  '처음',
#  '초롱',
#  '팬심',
#  '갈수록',
#  '내용',
#  '배경음악',
#  '달달',
#  '보고',
#  '완전',
#  '중간',
#  '본방',
#  '사수',
#  '스토리',
#  '흥미진진',
#  '배우',
#  '연기',
#  '어디',
#  '요새',
#  '수백향',
#  '인생',
#  '제목',
#  '화질',
#  '재미',
#  '가을로',
#  '가을',
#  '감동',
#  '때문',
#  '이건',
#  '벌써',
#  '퀄리티',
#  '일단',
#  '까지봣다',
#  '장국영',
#  '자살',
#  '사실',
#  '극적',
#  '뀰잼',
#  '뀰잼',
#  '느낌',
#  '예전',
#  '양심',
#  '냉장고',
#  '감정',
#  '움찔',
#  '한가지',
#  '부탁',
#  '연기자',
#  '보호',
#  '폭력',
#  '걱정',
#  '성추행',
#  '상가',
#  '모든',
#  '사람',
#  '목격',
#  '증언',
#  '덕분',
#  '청소년',
#  '계속',
#  '경찰서',
#  '남자',
#  '주인공',
#  '멋있쪙',
#  '재밋었다',
#  '영화',
#  '세기',
#  '최고',
#  '평점',
#  '사람',
#  '정말',
#  '비디오',
#  '친구',
#  '정말',
#  '느낌',
#  '지금',
#  '남기남',
#  '감독',
#  '이름',
#  '하나',
#  '진짜',
#  '최고다',
#  '최고',
#  '성룡',
#  '형님',
#  '마이',
#  '우상',
#  '당신',
#  '장르',
#  '이영화',
#  '영화',
#  '장르',
#  '지금',
#  '영화',
#  '최고다',
#  '리타',
#  '자꾸',
#  '생각',
#  '죄책감',
#  '도잠',
#  '보고',
#  '커서',
#  '다시',
#  '진짜',
#  '영화',
#  '웃음',
#  '감동',
#  '정치',
#  '대한',
#  '비판',
#  '묘사',
#  '표현',
#  '흥행',
#  '기억',
#  '안나',
#  '절대',
#  '평점',
#  '영화',
#  '생각',
#  '연기자',
#  '연기',
#  '디테',
#  '일만',
#  '봉임',
#  '대박',
#  '이건',
#  '한마디',
#  '사랑',
#  '달기',
#  '마음',
#  '수록',
#  '영화',
#  '살이',
#  '엇냐',
#  '남자',
#  '얼굴',
#  '성격',
#  '만점',
#  '다음',
#  '초반',
#  '설정',
#  '몰입',
#  '점차',
#  '이건',
#  '판타지',
#  '우리',
#  '미래',
#  '현실',
#  '언론',
#  '탄압',
#  '대한',
#  '은유',
#  '생각',
#  '남자',
#  '주인공',
#  '오카다',
#  '예상',
#  '기대',
#  '의외',
#  '재미',
#  '감동',
#  '인도영화',
#  '역시',
#  '스토리',
#  '영상',
#  '배우',
#  '연기',
#  '하나',
#  '영화',
#  '대박',
#  '감동',
#  '진짜',
#  '웃음',
#  '무엇',
#  '다그',
#  '허정무',
#  '대신',
#  '장외룡',
#  '감독',
#  '한국',
#  '고고싱',
#  '어찌',
#  '명감',
#  '정말',
#  '계속',
#  '미소',
#  '보조개',
#  '정말',
#  '메이',
#  '최고봉',
#  '하나',
#  '초딩',
#  '진짜',
#  '봣음',
#  '비포미드나잇',
#  '마지막',
#  '심정',
#  '또한',
#  '한편',
#  '모습',
#  '절로',
#  '웃음',
#  '재미',
#  '뭔가',
#  '스케',
#  '라디오',
#  '임진강',
#  '눈물',
#  '한석규',
#  '연기',
#  '쵝오',
#  '진짜',
#  '허니',
#  '꿀잼',
#  '개꿀잼',
#  '한예슬',
#  '진짜',
#  '원래',
#  '헤어',
#  '메이크업',
#  '드라마',
#  '내용',
#  '한마디',
#  '최고',
#  '재미',
#  '기대',
#  '더욱',
#  '명작',
#  '정말',
#  '완전',
#  '훈남',
#  '쉐프',
#  '보구',
#  '요리',
#  '시나리오',
#  '비고',
#  '연기',
#  '잼잼꿀잼',
#  '허니',
#  '잼핵잼잼잼',
#  '개인',
#  '언제',
#  '팬텀',
#  '크리스틴',
#  '일이',
#  '전혀',
#  '스토리',
#  '처럼',
#  '크리스틴',
#  '다시',
#  '남편',
#  '아쉬움',
#  '개인',
#  '알파',
#  '치노',
#  '때문',
#  '영화',
#  '처음',
#  '명화',
#  '다시',
#  '뮤지컬',
#  '역대',
#  '이건',
#  '정말',
#  '대부',
#  '바람',
#  '레벨',
#  '영화',
#  '명의',
#  '주인공',
#  '마치',
#  '뮤지컬',
#  '마잭',
#  '마돈나',
#  '엘비스급',
#  '노래실력',
#  '바비',
#  '바스코',
#  '이번',
#  '결과',
#  '대해',
#  '불만',
#  '사람',
#  '어쩌면',
#  '거지',
#  '바비',
#  '아이돌',
#  '어쩌',
#  '바비',
#  '자격',
#  '개인',
#  '생각',
#  '코미디',
#  '사극',
#  '장혁',
#  '명품',
#  '연기',
#  '가족',
#  '이서',
#  '영화',
#  '처음',
#  '마련',
#  '사마',
#  '그날',
#  '저녁',
#  '영화',
#  '기분',
#  '수가',
#  '옛날',
#  '워낭소리',
#  '진짜',
#  '인생',
#  '최고',
#  '명작',
#  '더빙',
#  '자막',
#  '연말',
#  '추천',
#  '영화',
#  '배경음악',
#  '한국',
#  '사회',
#  '치부',
#  '예언',
#  '수작',
#  '영화',
#  '진짜',
#  '영화',
#  '지금',
#  '엣날',
#  '제일',
#  '영화',
#  '역시',
#  '최고',
#  '슈퍼',
#  '울트라',
#  '노막',
#  '매력',
#  '중동',
#  '문화',
#  '대해',
#  '영화',
#  '참여',
#  '얼마나',
#  '아버지',
#  '이자',
#  '남편',
#  '무사',
#  '로서',
#  '남자',
#  '일생',
#  '의미',
#  '죽음',
#  '일지',
#  '자신',
#  '신념',
#  '진일',
#  '웃음',
#  '감동',
#  '물결',
#  '기대',
#  '쵝오임',
#  '영화',
#  '다만',
#  '엔딩',
#  '주인공',
#  '배심원',
#  '상대로',
#  '일장',
#  '연설',
#  '작위',
#  '신파',
#  '연설',
#  '배심원',
#  '무죄',
#  '만점',
#  '감동',
#  '정말',
#  '애정',
#  '이야기',
#  '정말',
#  '멜로',
#  '드라마',
#  '정말',
#  '최영장군',
#  '이민호',
#  '이민호',
#  '드라마',
#  '최고',
#  '생각',
#  '영화',
#  '보고',
#  '안치환',
#  '방향',
#  '노래',
#  '제목',
#  '스토리',
#  '세기',
#  '최고',
#  '걸작',
#  '안보',
#  '고도',
#  '오스트레일리아',
#  '조금',
#  '프랑스',
#  '코미디',
#  '영화',
#  '생각',
#  '영화',
#  '액션',
#  '별로',
#  '심장',
#  '쫄깃하',
#  '메이드',
#  '범죄물',
#  '류승범',
#  '황정민',
#  '연기',
#  '영화',
#  '기쁨',
#  '등장인물',
#  '캐릭터',
#  '절제',
#  '감정',
#  '영화',
#  '소설가',
#  '시나리오',
#  '무척',
#  '엄마',
#  '운전',
#  '맥거핀',
#  '아이맥스',
#  '개봉',
#  '이영화',
#  '선택',
#  '거임',
#  '완죤',
#  '스타',
#  '정부',
#  '국민',
#  '의지',
#  '정부',
#  '소재',
#  '퀘벡',
#  '영화',
#  '거지',
#  '벌써',
#  '호킹',
#  '능욕',
#  '영화',
#  '사람',
#  '감독',
#  '영화',
#  '정말',
#  '진짜',
#  '보통',
#  '전쟁영화',
#  '감독',
#  '특유',
#  '연출',
#  '감동',
#  '원작',
#  '스토리',
#  '강추',
#  '이정현',
#  '연기',
#  '소재',
#  '현실',
#  '전형',
#  '사이코',
#  '영화',
#  '우릴',
#  '욕망',
#  '명대사',
#  '기억',
#  '영화',
#  '더빙',
#  '똥칠',
#  '된거',
#  '점도',
#  '영화',
#  '블레이드러너',
#  '버금',
#  '영화',
#  '한국',
#  '결코',
#  '장면',
#  '정일우',
#  '상투',
#  '표현',
#  '영화',
#  '여운',
#  '감독',
#  '존경',
#  '반지',
#  '제왕',
#  '피터',
#  '잭슨',
#  '명작',
#  '지금',
#  '한번',
#  '감독판',
#  '정말',
#  '추억',
#  '영화',
#  '아버지',
#  '녹화',
#  '다시',
#  '리메이크',
#  '인생',
#  '최고',
#  '드라마',
#  '그대',
#  '무협',
#  '최고',
#  '재미',
#  '감동',
#  '보너스',
#  '시내',
#  '자신',
#  '용이',
#  '보신',
#  '추강',
#  '정말',
#  '아이',
#  '만화영화',
#  '액션영화',
#  '서도',
#  '귀수',
#  '아군',
#  '첫사랑',
#  '설레임',
#  '그대로',
#  '영화',
#  '만점',
#  '하나',
#  '명작',
#  '영화',
#  '시절',
#  '영화',
#  '관람',
#  '내내',
#  '향수',
#  '기분',
#  '김민선',
#  '김규리',
#  '여신',
#  '미모',
#  '연기',
#  '힐링',
#  '무비',
#  '영화',
#  '자리',
#  '연속',
#  '전혀',
#  '질리',
#  '외계인',
#  '신분',
#  '라이언',
#  '언제',
#  '기분',
#  '애니',
#  '보고',
#  '진짜',
#  '대박',
#  '코드',
#  '당시',
#  '사회',
#  '반영',
#  '짜임새',
#  '스토리',
#  '러브',
#  '모드',
#  '여주',
#  '매력',
#  '어요',
#  '얼굴',
#  '여주',
#  '하나요',
#  '만점',
#  '생각',
#  '영화',
#  '시간여행',
#  '스토리',
#  '사람',
#  '라면',
#  '트릴',
#  '영화',
#  '정말',
#  '보고',
#  '방송',
#  '털털',
#  '인간',
#  '실제',
#  '시기',
#  '나중',
#  '다시',
#  '정치',
#  '입문',
#  '정치',
#  '시기',
#  '가연',
#  '물감',
#  '액션',
#  '가족',
#  '애가',
#  '주제',
#  '영화',
#  '한국',
#  '배급사',
#  '언제',
#  '평점',
#  '감독',
#  '진짜',
#  '싸이코패스',
#  '영화',
#  '안인숙',
#  '연기',
#  '이편',
#  '조각',
#  '정말',
#  '재밋',
#  '추천',
#  '배우',
#  '연기',
#  '매우',
#  '용도',
#  '흥미진진',
#  '배우',
#  '케미',
#  '최고',
#  '다시',
#  '정말',
#  '이예',
#  '여유',
#  '일요일',
#  '오후',
#  '동화',
#  '세계',
#  '영화',
#  '스타워즈',
#  '쌍탑',
#  '영화',
#  '일견',
#  '더욱',
#  '감동',
#  ...]

# %%
# 단어별 개수 세기
counts = Counter(noun_list2)

# %%
tags = counts.most_common(200)
tags
# Out:
# [('영화', 985),
#  ('정말', 265),
#  ('최고', 230),
#  ('진짜', 184),
#  ('감동', 155),
#  ('연기', 142),
#  ('생각', 140),
#  ('드라마', 121),
#  ('보고', 119),
#  ('사람', 110),
#  ('평점', 103),
#  ('다시', 94),
#  ('마지막', 80),
#  ('사랑', 78),
#  ('스토리', 69),
#  ('작품', 67),
#  ('지금', 66),
#  ('배우', 65),
#  ('명작', 61),
#  ('재미', 59),
#  ('마음', 56),
#  ('하나', 54),
#  ('완전', 53),
#  ('이영화', 52),
#  ('추천', 50),
#  ('장면', 49),
#  ('매력', 49),
#  ('느낌', 47),
#  ('감독', 47),
#  ('내용', 46),
#  ('현실', 46),
#  ('액션', 45),
#  ('이야기', 43),
#  ('그냥', 43),
#  ('가슴', 43),
#  ('주인공', 42),
#  ('정도', 42),
#  ('이해', 40),
#  ('한번', 40),
#  ('인생', 38),
#  ('역시', 37),
#  ('음악', 37),
#  ('처음', 36),
#  ('기억', 35),
#  ('여운', 35),
#  ('남자', 34),
#  ('눈물', 34),
#  ('우리', 34),
#  ('인간', 33),
#  ('시간', 33),
#  ('대박', 32),
#  ('한국', 32),
#  ('결말', 30),
#  ('가족', 30),
#  ('모습', 29),
#  ('연기력', 29),
#  ('최고다', 27),
#  ('대한', 26),
#  ('영상', 26),
#  ('보기', 26),
#  ('아이', 26),
#  ('가장', 26),
#  ('소재', 25),
#  ('모든', 25),
#  ('연출', 25),
#  ('여자', 25),
#  ('시리즈', 24),
#  ('모두', 24),
#  ('개인', 24),
#  ('부분', 24),
#  ('반전', 23),
#  ('때문', 23),
#  ('계속', 23),
#  ('무엇', 23),
#  ('당시', 22),
#  ('공감', 22),
#  ('긴장감', 21),
#  ('자신', 21),
#  ('이건', 21),
#  ('사실', 20),
#  ('몰입', 20),
#  ('전쟁', 20),
#  ('기대', 20),
#  ('대해', 20),
#  ('그녀', 20),
#  ('오늘', 20),
#  ('강추', 19),
#  ('캐릭터', 19),
#  ('뭔가', 19),
#  ('노래', 19),
#  ('세상', 19),
#  ('아주', 19),
#  ('감정', 18),
#  ('수작', 18),
#  ('한국영', 18),
#  ('중간', 18),
#  ('제목', 18),
#  ('표현', 18),
#  ('코미디', 18),
#  ('엔딩', 18),
#  ('이상', 18),
#  ('간만', 18),
#  ('실화', 17),
#  ('요즘', 17),
#  ('후회', 17),
#  ('기분', 17),
#  ('제일', 17),
#  ('엄마', 17),
#  ('추억', 17),
#  ('애니', 17),
#  ('배경', 17),
#  ('코믹', 17),
#  ('라면', 16),
#  ('제대로', 16),
#  ('스릴러', 16),
#  ('친구', 16),
#  ('내내', 16),
#  ('별로', 16),
#  ('웃음', 16),
#  ('나이', 15),
#  ('조금', 15),
#  ('개봉', 15),
#  ('재밋', 15),
#  ('소름', 15),
#  ('몰입도', 15),
#  ('티비', 14),
#  ('성룡', 14),
#  ('만점', 14),
#  ('사회', 14),
#  ('걸작', 14),
#  ('웃기', 14),
#  ('인상', 14),
#  ('약간', 14),
#  ('다운', 14),
#  ('기도', 14),
#  ('보지', 14),
#  ('스릴', 13),
#  ('매우', 13),
#  ('원작', 13),
#  ('절대', 13),
#  ('전혀', 13),
#  ('나름', 13),
#  ('대사', 13),
#  ('예술', 13),
#  ('공포', 12),
#  ('갈수록', 12),
#  ('언제', 12),
#  ('실제', 12),
#  ('다른', 12),
#  ('완성', 12),
#  ('진심', 12),
#  ('영화관', 12),
#  ('레전드', 12),
#  ('가지', 12),
#  ('더욱', 11),
#  ('다큐', 11),
#  ('당신', 11),
#  ('초딩', 11),
#  ('이유', 11),
#  ('얘기', 11),
#  ('재밋다', 11),
#  ('혼자', 11),
#  ('짱짱', 11),
#  ('전개', 11),
#  ('감명', 11),
#  ('위해', 11),
#  ('시절', 10),
#  ('존재', 10),
#  ('얼굴', 10),
#  ('이제', 10),
#  ('이름', 10),
#  ('한마디', 10),
#  ('꿀잼', 10),
#  ('아버지', 10),
#  ('의미', 10),
#  ('아픔', 10),
#  ('희망', 10),
#  ('이후', 10),
#  ('분위기', 10),
#  ('극장', 10),
#  ('제작', 10),
#  ('통해', 9),
#  ('우리나라', 9),
#  ('화이팅', 9),
#  ('충격', 9),
#  ('어디', 9),
#  ('여배우', 9),
#  ('흥미진진', 9),
#  ('시작', 9),
#  ('선택', 9),
#  ('자꾸', 9),
#  ('얼마나', 9),
#  ('그대로', 9),
#  ('관람', 9),
#  ('세계', 9),
#  ('목소리', 9),
#  ('집중', 9),
#  ('발견', 9),
#  ('자연', 9),
#  ('영화로', 9)]

# %%
dic = dict(tags)
dic
# Out:
# {'영화': 985,
#  '정말': 265,
#  '최고': 230,
#  '진짜': 184,
#  '감동': 155,
#  '연기': 142,
#  '생각': 140,
#  '드라마': 121,
#  '보고': 119,
#  '사람': 110,
#  '평점': 103,
#  '다시': 94,
#  '마지막': 80,
#  '사랑': 78,
#  '스토리': 69,
#  '작품': 67,
#  '지금': 66,
#  '배우': 65,
#  '명작': 61,
#  '재미': 59,
#  '마음': 56,
#  '하나': 54,
#  '완전': 53,
#  '이영화': 52,
#  '추천': 50,
#  '장면': 49,
#  '매력': 49,
#  '느낌': 47,
#  '감독': 47,
#  '내용': 46,
#  '현실': 46,
#  '액션': 45,
#  '이야기': 43,
#  '그냥': 43,
#  '가슴': 43,
#  '주인공': 42,
#  '정도': 42,
#  '이해': 40,
#  '한번': 40,
#  '인생': 38,
#  '역시': 37,
#  '음악': 37,
#  '처음': 36,
#  '기억': 35,
#  '여운': 35,
#  '남자': 34,
#  '눈물': 34,
#  '우리': 34,
#  '인간': 33,
#  '시간': 33,
#  '대박': 32,
#  '한국': 32,
#  '결말': 30,
#  '가족': 30,
#  '모습': 29,
#  '연기력': 29,
#  '최고다': 27,
#  '대한': 26,
#  '영상': 26,
#  '보기': 26,
#  '아이': 26,
#  '가장': 26,
#  '소재': 25,
#  '모든': 25,
#  '연출': 25,
#  '여자': 25,
#  '시리즈': 24,
#  '모두': 24,
#  '개인': 24,
#  '부분': 24,
#  '반전': 23,
#  '때문': 23,
#  '계속': 23,
#  '무엇': 23,
#  '당시': 22,
#  '공감': 22,
#  '긴장감': 21,
#  '자신': 21,
#  '이건': 21,
#  '사실': 20,
#  '몰입': 20,
#  '전쟁': 20,
#  '기대': 20,
#  '대해': 20,
#  '그녀': 20,
#  '오늘': 20,
#  '강추': 19,
#  '캐릭터': 19,
#  '뭔가': 19,
#  '노래': 19,
#  '세상': 19,
#  '아주': 19,
#  '감정': 18,
#  '수작': 18,
#  '한국영': 18,
#  '중간': 18,
#  '제목': 18,
#  '표현': 18,
#  '코미디': 18,
#  '엔딩': 18,
#  '이상': 18,
#  '간만': 18,
#  '실화': 17,
#  '요즘': 17,
#  '후회': 17,
#  '기분': 17,
#  '제일': 17,
#  '엄마': 17,
#  '추억': 17,
#  '애니': 17,
#  '배경': 17,
#  '코믹': 17,
#  '라면': 16,
#  '제대로': 16,
#  '스릴러': 16,
#  '친구': 16,
#  '내내': 16,
#  '별로': 16,
#  '웃음': 16,
#  '나이': 15,
#  '조금': 15,
#  '개봉': 15,
#  '재밋': 15,
#  '소름': 15,
#  '몰입도': 15,
#  '티비': 14,
#  '성룡': 14,
#  '만점': 14,
#  '사회': 14,
#  '걸작': 14,
#  '웃기': 14,
#  '인상': 14,
#  '약간': 14,
#  '다운': 14,
#  '기도': 14,
#  '보지': 14,
#  '스릴': 13,
#  '매우': 13,
#  '원작': 13,
#  '절대': 13,
#  '전혀': 13,
#  '나름': 13,
#  '대사': 13,
#  '예술': 13,
#  '공포': 12,
#  '갈수록': 12,
#  '언제': 12,
#  '실제': 12,
#  '다른': 12,
#  '완성': 12,
#  '진심': 12,
#  '영화관': 12,
#  '레전드': 12,
#  '가지': 12,
#  '더욱': 11,
#  '다큐': 11,
#  '당신': 11,
#  '초딩': 11,
#  '이유': 11,
#  '얘기': 11,
#  '재밋다': 11,
#  '혼자': 11,
#  '짱짱': 11,
#  '전개': 11,
#  '감명': 11,
#  '위해': 11,
#  '시절': 10,
#  '존재': 10,
#  '얼굴': 10,
#  '이제': 10,
#  '이름': 10,
#  '한마디': 10,
#  '꿀잼': 10,
#  '아버지': 10,
#  '의미': 10,
#  '아픔': 10,
#  '희망': 10,
#  '이후': 10,
#  '분위기': 10,
#  '극장': 10,
#  '제작': 10,
#  '통해': 9,
#  '우리나라': 9,
#  '화이팅': 9,
#  '충격': 9,
#  '어디': 9,
#  '여배우': 9,
#  '흥미진진': 9,
#  '시작': 9,
#  '선택': 9,
#  '자꾸': 9,
#  '얼마나': 9,
#  '그대로': 9,
#  '관람': 9,
#  '세계': 9,
#  '목소리': 9,
#  '집중': 9,
#  '발견': 9,
#  '자연': 9,
#  '영화로': 9}

# %% [markdown]
# ### 워드클라우드 생성

# %%
from PIL import Image # 워드클라우드용 마스크를 생성하기 위한 라이브러리
import matplotlib.pyplot as plt

custom_mask = np.array(Image.open('포도주스.jfif'))
plt.figure(figsize=(8,8))
plt.imshow(custom_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(custom_mask) #마스크용 사진의 색을 입력

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(font_path = 'NanumSquareNeo-aLt.ttf', background_color='black', width=800, height=600,
                      max_words=200, mask=custom_mask, max_font_size=30)
print(dict(tags))
cloud = wordcloud.generate_from_frequencies(dict(tags))
plt.figure(figsize=(12,12))
plt.axis('off')
plt.imshow(cloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.show()
# Out:
# {'영화': 985, '정말': 265, '최고': 230, '진짜': 184, '감동': 155, '연기': 142, '생각': 140, '드라마': 121, '보고': 119, '사람': 110, '평점': 103, '다시': 94, '마지막': 80, '사랑': 78, '스토리': 69, '작품': 67, '지금': 66, '배우': 65, '명작': 61, '재미': 59, '마음': 56, '하나': 54, '완전': 53, '이영화': 52, '추천': 50, '장면': 49, '매력': 49, '느낌': 47, '감독': 47, '내용': 46, '현실': 46, '액션': 45, '이야기': 43, '그냥': 43, '가슴': 43, '주인공': 42, '정도': 42, '이해': 40, '한번': 40, '인생': 38, '역시': 37, '음악': 37, '처음': 36, '기억': 35, '여운': 35, '남자': 34, '눈물': 34, '우리': 34, '인간': 33, '시간': 33, '대박': 32, '한국': 32, '결말': 30, '가족': 30, '모습': 29, '연기력': 29, '최고다': 27, '대한': 26, '영상': 26, '보기': 26, '아이': 26, '가장': 26, '소재': 25, '모든': 25, '연출': 25, '여자': 25, '시리즈': 24, '모두': 24, '개인': 24, '부분': 24, '반전': 23, '때문': 23, '계속': 23, '무엇': 23, '당시': 22, '공감': 22, '긴장감': 21, '자신': 21, '이건': 21, '사실': 20, '몰입': 20, '전쟁': 20, '기대': 20, '대해': 20, '그녀': 20, '오늘': 20, '강추': 19, '캐릭터': 19, '뭔가': 19, '노래': 19, '세상': 19, '아주': 19, '감정': 18, '수작': 18, '한국영': 18, '중간': 18, '제목': 18, '표현': 18, '코미디': 18, '엔딩': 18, '이상': 18, '간만': 18, '실화': 17, '요즘': 17, '후회': 17, '기분': 17, '제일': 17, '엄마': 17, '추억': 17, '애니': 17, '배경': 17, '코믹': 17, '라면': 16, '제대로': 16, '스릴러': 16, '친구': 16, '내내': 16, '별로': 16, '웃음': 16, '나이': 15, '조금': 15, '개봉': 15, '재밋': 15, '소름': 15, '몰입도': 15, '티비': 14, '성룡': 14, '만점': 14, '사회': 14, '걸작': 14, '웃기': 14, '인상': 14, '약간': 14, '다운': 14, '기도': 14, '보지': 14, '스릴': 13, '매우': 13, '원작': 13, '절대': 13, '전혀': 13, '나름': 13, '대사': 13, '예술': 13, '공포': 12, '갈수록': 12, '언제': 12, '실제': 12, '다른': 12, '완성': 12, '진심': 12, '영화관': 12, '레전드': 12, '가지': 12, '더욱': 11, '다큐': 11, '당신': 11, '초딩': 11, '이유': 11, '얘기': 11, '재밋다': 11, '혼자': 11, '짱짱': 11, '전개': 11, '감명': 11, '위해': 11, '시절': 10, '존재': 10, '얼굴': 10, '이제': 10, '이름': 10, '한마디': 10, '꿀잼': 10, '아버지': 10, '의미': 10, '아픔': 10, '희망': 10, '이후': 10, '분위기': 10, '극장': 10, '제작': 10, '통해': 9, '우리나라': 9, '화이팅': 9, '충격': 9, '어디': 9, '여배우': 9, '흥미진진': 9, '시작': 9, '선택': 9, '자꾸': 9, '얼마나': 9, '그대로': 9, '관람': 9, '세계': 9, '목소리': 9, '집중': 9, '발견': 9, '자연': 9, '영화로': 9}
